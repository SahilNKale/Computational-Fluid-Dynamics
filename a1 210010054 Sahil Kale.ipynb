# %%
# %matplotlib inline
from math import*
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# ## Q.1

# %%
def vel(r,t):
    x,y=r
    if np.sqrt(x*x+y*y)>1:
        return np.array([((x*x-y*y-1)*(x*x-y*y) + 4*(x**2)*(y**2))/((x*x+y*y)**2),(-2*x*y)/((x*x+y*y)**2)])
    else:
        return np.array([0,0])

# %% [markdown]
# ## Pathlines & Streamlines

# %%
for j in range(-5,5):
    IC=np.array([-2,j])
    t=np.linspace(0,6,100)
    Sx,Sy=odeint(vel,IC,t).T
    plt.plot(Sx,Sy)
plt.grid()
plt.legend(['Pathlines & Streamlines'],loc='upper right')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Velicty Field

# %%
x,y=np.mgrid[-2:2:15j,-2:2:15j]

# %%
V=np.zeros_like(x)
U=np.zeros_like(x)
for i in range(len(x)):
    for j in range(len(y)):
        U[i][j],V[i][j]=vel([x[i][j],y[i][j]],1)
plt.quiver(x,y,U,V,color='r')

# %% [markdown]
# ## Streaklines

# %%
for j in range(-5,5):
    IC=np.array([-2.0,j])
    dt=0.1
    n=100
    T=n*dt
    Sx1,Sy1=[],[]
    for i in range(n):
            start = i*dt
            res = odeint(vel, IC, [start, T])
            Sx1.append(res[1,0])
            Sy1.append(res[1,1])
    plt.plot(Sx1, Sy1)
plt.grid()
plt.legend(['Streakline'],loc='upper right')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Q.2

# %%
def vel2(r,t):
    x,y=r
    if(np.sqrt((x+t)*(x+t) + y*y)>1):
        return np.array([-((x+t)**2-y**2)/(((x+t)**2+y**2)**2),-2*(x+t)*y/((x+t)**2+y**2)**2])
    else:
        return np.array([0,0])

# %% [markdown]
# ## Streamlines

# %% [markdown]
# #### At T=0s

# %%
def velt1(r,t=1):
    return vel2(r,0)
for i in range(50):
    IC=np.array([-2,-2+0.08*i])
    t=np.linspace(0,70,100)
    SsX1,SsX2=odeint(velt1,IC,t).T
    plt.plot(SsX1,SsX2)
plt.grid()
plt.axis('equal')
# Out:
# (-6.402209049696168, 2.040230031531469, -5.317107695737183, 5.317107695737183)

# %% [markdown]
# ##  T=0.5s

# %%
def velt1(r,t=1):
    return vel2(r,0.5)
for i in range(50):
    IC=np.array([-2,-2+0.08*i])
    t=np.linspace(0,70,100)
    SsX1,SsX2=odeint(velt1,IC,t).T
    plt.plot(SsX1,SsX2)
plt.grid()
plt.axis('equal')
# Out:
# (-6.864675403717054, 1.6950824884613807, -5.264392586558473, 5.264392586558473)

# %% [markdown]
# #### At T=1s

# %%
def velt1(r,t=1):
    return vel2(r,1)

# %%
for i in range(50):
    IC=np.array([-5,-5+0.08*i])
    t=np.linspace(0,70,100)
    SsX1,SsX2=odeint(velt1,IC,t).T
    plt.plot(SsX1,SsX2)
plt.grid()
plt.axis('equal')
# Out:
# (-7.017537541295913, -4.29101013997567, -6.63340389197837, -0.8155521956200777)

# %% [markdown]
# ##  T=1.25s

# %%
def velt1(r,t=1):
    return vel2(r,1.25)
for i in range(20):
    IC=np.array([-2,-2+0.01*i])
    t=np.linspace(0,50,100)
    SsX1,SsX2=odeint(velt1,IC,t).T
    plt.plot(SsX1,SsX2)
plt.grid()
plt.axis('equal')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\scipy\integrate\odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# (-2.1, 0.1, -2.395284185694573, 0.11406115169974157)

# %% [markdown]
# ## Pathlines

# %%
for j in range(80):
    if(j!=0): 
        IC=np.array([-2,-2+0.05*j])
        t=np.linspace(0,6,100)
        Sx2,Sy2=odeint(vel2,IC,t).T
        plt.plot(Sx2,Sy2)
plt.grid()
#plt.axis('equal')
plt.legend(['Pathline'])
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Velocity Field

# %% [markdown]
# #### At T=1

# %%
def vel22(r,t):
    x,y=r
    if(np.sqrt((x+t)*(x+t) + y*y)>1):
        return np.array([-((x+t)**2-y**2)/(((x+t)**2+y**2)**2),-2*(x+t)*y/((x+t)**2+y**2)**2])
    else:
        return np.array([0,0])
x,y=np.mgrid[-2:2:20j,-2:2:20j]
V=np.zeros_like(x)
U=np.zeros_like(x)
for i in range(len(x)):
    for j in range(len(y)):
        U[i][j],V[i][j]=vel22([x[i][j],y[i][j]],1)
plt.quiver(x,y,U,V,color='r')

# %% [markdown]
# ## At T=2s

# %%
V=np.zeros_like(x)
U=np.zeros_like(x)
for i in range(len(x)):
    for j in range(len(y)):
        U[i][j],V[i][j]=vel22([x[i][j],y[i][j]],2)
plt.quiver(x,y,U,V,color='r')

# %%
V=np.zeros_like(x)
U=np.zeros_like(x)
for i in range(len(x)):
    for j in range(len(y)):
        U[i][j],V[i][j]=vel22([x[i][j],y[i][j]],3)
plt.quiver(x,y,U,V,color='r')

# %%
V=np.zeros_like(x)
U=np.zeros_like(x)
for i in range(len(x)):
    for j in range(len(y)):
        U[i][j],V[i][j]=vel22([x[i][j],y[i][j]],5)
plt.quiver(x,y,U,V,color='r')

# %% [markdown]
# ## Streaklines

# %%
for j in range(15):
    if(j!=0):
        IC=np.array([-2,-2+0.3*j])
        dt=0.1
        n=60
        T=n*dt
        Sx22,Sy22=[],[]
        for i in range(n):
                start = i*dt
                res = odeint(vel22, IC, [start, T])
                Sx22.append(res[1,0])
                Sy22.append(res[1,1])
        plt.plot(Sx22, Sy22)
plt.grid()
plt.legend(['Streaklines'])
